# %% [markdown]
# # Data Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('hospital_readmissions.csv')
df.head()
# Out:
#        age  time_in_hospital  n_lab_procedures  n_procedures  n_medications  \
# 0  [70-80)                 8                72             1             18
# 1  [70-80)                 3                34             2             13
# 2  [50-60)                 5                45             0             18
# 3  [70-80)                 2                36             0             12
# 4  [60-70)                 1                42             0              7
#
#    n_outpatient  n_inpatient  n_emergency medical_specialty       diag_1  \
# 0             2            0            0           Missing  Circulatory
# 1             0            0            0             Other        Other
# 2             0            0            0           Missing  Circulatory
# 3             1            0            0           Missing  Circulatory
# 4             0            0            0  InternalMedicine        Other
#
#         diag_2       diag_3 glucose_test A1Ctest change diabetes_med  \
# 0  Respiratory        Other           no      no     no          yes
# 1        Other        Other           no      no     no          yes
# 2  Circulatory  Circulatory           no      no    yes          yes
# 3        Other     Diabetes           no      no    yes          yes
# 4  Circulatory  Respiratory           no      no     no          yes
#
#   readmitted
# 0         no
# 1         no
# 2        yes
# 3        yes
# 4         no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                25000 non-null  object
#  1   time_in_hospital   25000 non-null  int64
#  2   n_lab_procedures   25000 non-null  int64
#  3   n_procedures       25000 non-null  int64
#  4   n_medications      25000 non-null  int64
#  5   n_outpatient       25000 non-null  int64
#  6   n_inpatient        25000 non-null  int64
#  7   n_emergency        25000 non-null  int64
#  8   medical_specialty  25000 non-null  object
#  9   diag_1             25000 non-null  object
#  10  diag_2             25000 non-null  object
#  11  diag_3             25000 non-null  object
#  12  glucose_test       25000 non-null  object
#  13  A1Ctest            25000 non-null  object
#  14  change             25000 non-null  object
#  15  diabetes_med       25000 non-null  object
#  16  readmitted         25000 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 3.2+ MB

# %%
df.describe()
df.value_counts()
# Out:
# age       time_in_hospital  n_lab_procedures  n_procedures  n_medications  n_outpatient  n_inpatient  n_emergency  medical_specialty       diag_1           diag_2       diag_3       glucose_test  A1Ctest  change  diabetes_med  readmitted
# [40-50)   1                 1                 0             1              0             1            0            Missing                 Other            Other        Digestive    no            no       no      no            no            1
# [70-80)   4                 54                3             15             0             0            0            Missing                 Circulatory      Circulatory  Circulatory  no            no       yes     yes           no            1
#                             55                3             15             0             3            0            Family/GeneralPractice  Musculoskeletal  Diabetes     Other        no            no       no      yes           yes           1
#                                                             3              0             1            0            Missing                 Respiratory      Diabetes     Other        no            high     no      no            yes           1
#                                               2             20             0             0            0            Missing                 Injury           Other        Circulatory  no            no       no      no            no            1
#                                                                                                                                                                                                                                                 ..
# [60-70)   2                 38                0             12             0             0            0            Missing                 Respiratory      Diabetes     Circulatory  no            no       yes     yes           yes           1
#                                                             11             0             0            1            Missing                 Diabetes         Circulatory  Other        no            no       yes     yes           no            1
#                                                                                                       0            Missing                 Respiratory      Respiratory  Circulatory  no            high     no      no            no            1
#                                                             10             1             0            0            Missing                 Other            Other        Other        no            no       no      no            no            1
# [90-100)  14                87                5             31             0             0            0            Emergency/Trauma        Circulatory      Other        Circulatory  no            high     yes     yes           no            1
# Name: count, Length: 25000, dtype: int64

# %% [markdown]
# Encode Categorical Vales:

# %%
df = pd.get_dummies(df, columns=['medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'glucose_test', 'A1Ctest', 'change', 'diabetes_med'])

# %%
df.dtypes
# Out:
# age                                         object
# time_in_hospital                             int64
# n_lab_procedures                             int64
# n_procedures                                 int64
# n_medications                                int64
# n_outpatient                                 int64
# n_inpatient                                  int64
# n_emergency                                  int64
# readmitted                                  object
# medical_specialty_Cardiology                  bool
# medical_specialty_Emergency/Trauma            bool
# medical_specialty_Family/GeneralPractice      bool
# medical_specialty_InternalMedicine            bool
# medical_specialty_Missing                     bool
# medical_specialty_Other                       bool
# medical_specialty_Surgery                     bool
# diag_1_Circulatory                            bool
# diag_1_Diabetes                               bool
# diag_1_Digestive                              bool
# diag_1_Injury                                 bool
# diag_1_Missing                                bool
# diag_1_Musculoskeletal                        bool
# diag_1_Other                                  bool
# diag_1_Respiratory                            bool
# diag_2_Circulatory                            bool
# diag_2_Diabetes                               bool
# diag_2_Digestive                              bool
# diag_2_Injury                                 bool
# diag_2_Missing                                bool
# diag_2_Musculoskeletal                        bool
# diag_2_Other                                  bool
# diag_2_Respiratory                            bool
# diag_3_Circulatory                            bool
# diag_3_Diabetes                               bool
# diag_3_Digestive                              bool
# diag_3_Injury                                 bool
# diag_3_Missing                                bool
# diag_3_Musculoskeletal                        bool
# diag_3_Other                                  bool
# diag_3_Respiratory                            bool
# glucose_test_high                             bool
# glucose_test_no                               bool
# glucose_test_normal                           bool
# A1Ctest_high                                  bool
# A1Ctest_no                                    bool
# A1Ctest_normal                                bool
# change_no                                     bool
# change_yes                                    bool
# diabetes_med_no                               bool
# diabetes_med_yes                              bool
# dtype: object

# %%
df.head()
# Out:
#        age  time_in_hospital  n_lab_procedures  n_procedures  n_medications  \
# 0  [70-80)                 8                72             1             18
# 1  [70-80)                 3                34             2             13
# 2  [50-60)                 5                45             0             18
# 3  [70-80)                 2                36             0             12
# 4  [60-70)                 1                42             0              7
#
#    n_outpatient  n_inpatient  n_emergency readmitted  \
# 0             2            0            0         no
# 1             0            0            0         no
# 2             0            0            0        yes
# 3             1            0            0        yes
# 4             0            0            0         no
#
#    medical_specialty_Cardiology  ...  glucose_test_high  glucose_test_no  \
# 0                         False  ...              False             True
# 1                         False  ...              False             True
# 2                         False  ...              False             True
# 3                         False  ...              False             True
# 4                         False  ...              False             True
#
#    glucose_test_normal  A1Ctest_high  A1Ctest_no  A1Ctest_normal  change_no  \
# 0                False         False        True           False       True
# 1                False         False        True           False       True
# 2                False         False        True           False      False
# 3                False         False        True           False      False
# 4                False         False        True           False       True
#
#    change_yes  diabetes_med_no  diabetes_med_yes
# 0       False            False              True
# 1       False            False              True
# 2        True            False              True
# 3        True            False              True
# 4       False            False              True
#
# [5 rows x 50 columns]

# %%
df.head()
# Out:
#        age  time_in_hospital  n_lab_procedures  n_procedures  n_medications  \
# 0  [70-80)                 8                72             1             18
# 1  [70-80)                 3                34             2             13
# 2  [50-60)                 5                45             0             18
# 3  [70-80)                 2                36             0             12
# 4  [60-70)                 1                42             0              7
#
#    n_outpatient  n_inpatient  n_emergency readmitted  \
# 0             2            0            0         no
# 1             0            0            0         no
# 2             0            0            0        yes
# 3             1            0            0        yes
# 4             0            0            0         no
#
#    medical_specialty_Cardiology  ...  glucose_test_high  glucose_test_no  \
# 0                         False  ...              False             True
# 1                         False  ...              False             True
# 2                         False  ...              False             True
# 3                         False  ...              False             True
# 4                         False  ...              False             True
#
#    glucose_test_normal  A1Ctest_high  A1Ctest_no  A1Ctest_normal  change_no  \
# 0                False         False        True           False       True
# 1                False         False        True           False       True
# 2                False         False        True           False      False
# 3                False         False        True           False      False
# 4                False         False        True           False       True
#
#    change_yes  diabetes_med_no  diabetes_med_yes
# 0       False            False              True
# 1       False            False              True
# 2        True            False              True
# 3        True            False              True
# 4       False            False              True
#
# [5 rows x 50 columns]

# %%
df.head()
# Out:
#        age  time_in_hospital  n_lab_procedures  n_procedures  n_medications  \
# 0  [70-80)          0.538462          0.633929      0.166667       0.217949
# 1  [70-80)          0.153846          0.294643      0.333333       0.153846
# 2  [50-60)          0.307692          0.392857      0.000000       0.217949
# 3  [70-80)          0.076923          0.312500      0.000000       0.141026
# 4  [60-70)          0.000000          0.366071      0.000000       0.076923
#
#    n_outpatient  n_inpatient  n_emergency readmitted  \
# 0      0.060606          0.0          0.0         no
# 1      0.000000          0.0          0.0         no
# 2      0.000000          0.0          0.0        yes
# 3      0.030303          0.0          0.0        yes
# 4      0.000000          0.0          0.0         no
#
#    medical_specialty_Cardiology  ...  glucose_test_high  glucose_test_no  \
# 0                         False  ...              False             True
# 1                         False  ...              False             True
# 2                         False  ...              False             True
# 3                         False  ...              False             True
# 4                         False  ...              False             True
#
#    glucose_test_normal  A1Ctest_high  A1Ctest_no  A1Ctest_normal  change_no  \
# 0                False         False        True           False       True
# 1                False         False        True           False       True
# 2                False         False        True           False      False
# 3                False         False        True           False      False
# 4                False         False        True           False       True
#
#    change_yes  diabetes_med_no  diabetes_med_yes
# 0       False            False              True
# 1       False            False              True
# 2        True            False              True
# 3        True            False              True
# 4       False            False              True
#
# [5 rows x 50 columns]

# %%
quantitative_columns = ['time_in_hospital', 'n_lab_procedures', 'n_procedures', 'n_medications', 'n_outpatient', 'n_inpatient', 'n_emergency']

scaler = MinMaxScaler()
df[quantitative_columns] = scaler.fit_transform(df[quantitative_columns])

# %%
df.head()
# Out:
#        age  time_in_hospital  n_lab_procedures  n_procedures  n_medications  \
# 0  [70-80)          0.538462          0.633929      0.166667       0.217949
# 1  [70-80)          0.153846          0.294643      0.333333       0.153846
# 2  [50-60)          0.307692          0.392857      0.000000       0.217949
# 3  [70-80)          0.076923          0.312500      0.000000       0.141026
# 4  [60-70)          0.000000          0.366071      0.000000       0.076923
#
#    n_outpatient  n_inpatient  n_emergency readmitted  \
# 0      0.060606          0.0          0.0         no
# 1      0.000000          0.0          0.0         no
# 2      0.000000          0.0          0.0        yes
# 3      0.030303          0.0          0.0        yes
# 4      0.000000          0.0          0.0         no
#
#    medical_specialty_Cardiology  ...  glucose_test_high  glucose_test_no  \
# 0                         False  ...              False             True
# 1                         False  ...              False             True
# 2                         False  ...              False             True
# 3                         False  ...              False             True
# 4                         False  ...              False             True
#
#    glucose_test_normal  A1Ctest_high  A1Ctest_no  A1Ctest_normal  change_no  \
# 0                False         False        True           False       True
# 1                False         False        True           False       True
# 2                False         False        True           False      False
# 3                False         False        True           False      False
# 4                False         False        True           False       True
#
#    change_yes  diabetes_med_no  diabetes_med_yes
# 0       False            False              True
# 1       False            False              True
# 2        True            False              True
# 3        True            False              True
# 4       False            False              True
#
# [5 rows x 50 columns]

# %%
quantitative_columns = ['time_in_hospital', 'n_lab_procedures', 'n_procedures', 'n_medications', 'n_outpatient', 'n_inpatient', 'n_emergency']

scaler = MinMaxScaler()
df[quantitative_columns] = scaler.fit_transform(df[quantitative_columns])
